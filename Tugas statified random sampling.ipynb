# %%
import pandas as pd
data = pd.read_csv('MovieData-2018-2020.csv')
data
# Out:
#                        name rating      genre  year  \
# 0             A Quiet Place  PG-13      Drama  2018
# 1    Avengers: Infinity War  PG-13     Action  2018
# 2                Deadpool 2      R     Action  2018
# 3         Bohemian Rhapsody  PG-13  Biography  2018
# 4             Black Panther  PG-13     Action  2018
# ..                      ...    ...        ...   ...
# 269        Love by Drowning      R      Drama  2020
# 270           The Robinsons    NaN     Action  2020
# 271            More to Life    NaN      Drama  2020
# 272           Saving Mbango    NaN      Drama  2020
# 273            It's Just Us    NaN      Drama  2020
#
#                               released  score     votes           director  \
# 0        April 6, 2018 (United States)    7.5  456000.0     John Krasinski
# 1       April 27, 2018 (United States)    8.4  897000.0      Anthony Russo
# 2         May 18, 2018 (United States)    7.7  505000.0       David Leitch
# 3     November 2, 2018 (United States)    7.9  476000.0       Bryan Singer
# 4    February 16, 2018 (United States)    7.3  661000.0       Ryan Coogler
# ..                                 ...    ...       ...                ...
# 269   November 6, 2020 (United States)    NaN       NaN  Justin Kreinbrink
# 270  November 10, 2020 (United States)    NaN       NaN          Directors
# 271   October 23, 2020 (United States)    3.1      18.0      Joseph Ebanks
# 272          April 27, 2020 (Cameroon)    5.7      29.0       Nkanya Nkwai
# 273    October 1, 2020 (United States)    NaN       NaN      James Randall
#
#                    writer               star         country       budget  \
# 0             Bryan Woods        Emily Blunt   United States   17000000.0
# 1      Christopher Markus  Robert Downey Jr.   United States  321000000.0
# 2             Rhett Reese      Ryan Reynolds          Canada  110000000.0
# 3        Anthony McCarten         Rami Malek  United Kingdom   52000000.0
# 4            Ryan Coogler   Chadwick Boseman   United States  200000000.0
# ..                    ...                ...             ...          ...
# 269         C.E. Poverman       Nicky Whelan   United States    1000000.0
# 270  Aleks Alifirenko Jr.     Billy Hartmann   United States      10000.0
# 271         Joseph Ebanks       Shannon Bond   United States       7000.0
# 272          Lynno Lovert       Onyama Laura   United States      58750.0
# 273         James Randall      Christina Roz   United States      15000.0
#
#             gross                company  runtime
# 0    3.503204e+08     Paramount Pictures     90.0
# 1    2.048360e+09         Marvel Studios    149.0
# 2    7.864705e+08  Twentieth Century Fox    119.0
# 3    9.119026e+08  Twentieth Century Fox    134.0
# 4    1.347598e+09         Marvel Studios    134.0
# ..            ...                    ...      ...
# 269           NaN         Dow Jazz Films    121.0
# 270           NaN                    NaN     90.0
# 271           NaN                    NaN     90.0
# 272           NaN       Embi Productions      NaN
# 273           NaN                    NaN    120.0
#
# [274 rows x 15 columns]

# %%
#stratifed data by genre
from sklearn.model_selection import train_test_split

_, stratified_sample = train_test_split(
    data,
    test_size=0.3,
    stratify=data['genre'],
    random_state=1
)

stratified_sample
# Out:
#                                   name rating      genre  year  \
# 132                       Action Point      R     Comedy  2018
# 15                      BlacKkKlansman      R  Biography  2018
# 9    Spider-Man: Into the Spider-Verse     PG  Animation  2018
# 210                      Captive State  PG-13     Action  2019
# 18             Solo: A Star Wars Story  PG-13     Action  2018
# ..                                 ...    ...        ...   ...
# 87                       Hotel Artemis      R     Action  2018
# 57                           Bumblebee  PG-13     Action  2018
# 243                The Wandering Earth  TV-MA     Action  2019
# 153                         Knives Out  PG-13     Comedy  2019
# 261                  The Invisible Man      R      Drama  2020
#
#                               released  score     votes         director  \
# 132       June 1, 2018 (United States)    5.1   11000.0       Tim Kirkby
# 15     August 10, 2018 (United States)    7.5  236000.0        Spike Lee
# 9    December 14, 2018 (United States)    8.4  411000.0  Bob Persichetti
# 210     March 15, 2019 (United States)    6.0   51000.0     Rupert Wyatt
# 18        May 25, 2018 (United States)    6.9  306000.0       Ron Howard
# ..                                 ...    ...       ...              ...
# 87        June 8, 2018 (United States)    6.1   49000.0      Drew Pearce
# 57   December 21, 2018 (United States)    6.7  147000.0    Travis Knight
# 243           February 5, 2019 (China)    6.0   28000.0        Frant Gwo
# 153  November 27, 2019 (United States)    7.9  505000.0     Rian Johnson
# 261  February 28, 2020 (United States)    7.1  186000.0   Leigh Whannell
#
#                writer                   star         country       budget  \
# 132   John Altschuler       Johnny Knoxville   United States   19000000.0
# 15    Charlie Wachtel  John David Washington   United States   15000000.0
# 9           Phil Lord          Shameik Moore   United States   90000000.0
# 210      Erica Beeney           John Goodman   United States   25000000.0
# 18    Jonathan Kasdan       Alden Ehrenreich   United States  275000000.0
# ..                ...                    ...             ...          ...
# 87        Drew Pearce           Jodie Foster  United Kingdom   15000000.0
# 57   Christina Hodson       Hailee Steinfeld           China  135000000.0
# 243         Gong Geer                Jing Wu           China   48000000.0
# 153      Rian Johnson           Daniel Craig   United States   40000000.0
# 261    Leigh Whannell         Elisabeth Moss          Canada    7000000.0
#
#            gross                                            company  runtime
# 132    5103663.0                                 Paramount Pictures     85.0
# 15    93413709.0                                     Focus Features    135.0
# 9    375540831.0                  Sony Pictures Entertainment (SPE)    117.0
# 210    8808611.0                                        Participant    109.0
# 18   392924807.0                                          Lucasfilm    135.0
# ..           ...                                                ...      ...
# 87    13313581.0                                    The Ink Factory     94.0
# 57   467989645.0                                             Hasbro    114.0
# 243  699992512.0  Beijing Dengfeng International Culture Communi...    125.0
# 153  311539397.0                                          Lionsgate    130.0
# 261  143151000.0                                 Universal Pictures    124.0
#
# [82 rows x 15 columns]

# %%
# Melihat jumlah Data Setiap Gendre
data["genre"].value_counts()
# Out:
# genre
# Action       88
# Comedy       45
# Drama        38
# Biography    29
# Animation    23
# Adventure    19
# Horror       15
# Crime        12
# Fantasy       3
# Name: count, dtype: int64

# %%
# Mengambil 30 data teratas
sample = stratified_sample.head(30)
sample
# Out:
#                                   name rating      genre  year  \
# 250   United States    6000000.0   21150265.0
# 10    United States  178000000.0  791657398.0
# 96    United States   12000000.0   91244913.0
# 97          Iceland    2000000.0    4165776.0
# 126   United States   19000000.0   46664414.0
# 152   United States   75000000.0  327281779.0
# 176   United States   10000000.0   10209813.0
# 124   United States    5500000.0   18160930.0
# 14    United States  162000000.0  622674139.0
# 47    United States   32000000.0   31882724.0
# 42    United States   62000000.0  190400157.0
# 171  United Kingdom   13000000.0  237860050.0
#
#                                company  runtime
# 132                 Paramount Pictures     85.0
# 15                      Focus Features    135.0
# 9    Sony Pictures Entertainment (SPE)    117.0
# 210                        Participant    109.0
# 18                           Lucasfilm    135.0
# 44                Access Entertainment    100.0
# 144                  Columbia Pictures    161.0
# 103                  ShivHans Pictures     99.0
# 64                   Goalpost Pictures    100.0
# 101                    New Line Cinema    105.0
# 41                      Atomic Monster     96.0
# 225                         Iconoclast     95.0
# 76                       Company Films    107.0
# 264                 Universal Pictures    101.0
# 20               Vendian Entertainment    139.0
# 170                 Paramount Pictures    128.0
# 56                 Lucamar Productions    130.0
# 207               Walt Disney Pictures    119.0
# 250                     Orion Pictures     92.0
# 10                  Paramount Pictures    147.0
# 96           Metro-Goldwyn-Mayer (MGM)    112.0
# 97                        Armory Films     98.0
# 126               Summit Entertainment    103.0
# 152                          Lionsgate    130.0
# 176                       Astute Films    133.0
# 124                          CBS Films     89.0
# 14                      Marvel Studios    118.0
# 47                    Goddard Textiles    141.0
# 42                   Columbia Pictures    121.0
# 171         Carnival Film & Television    122.0

# %%
# Menghitung Rata-Rata dan Standar Deviasi
print("Rata-rata Budget :", sample['budget'].mean())
print("Standar Deviasi :", sample['budget'].std())
# Out:
# Rata-rata Budget : 63766666.666666664
# Standar Deviasi : 74316626.13130544

# %% [markdown]
# MENGHITUNG ESTIMASI

# %%
import scipy.stats as stats
import math

# Specify sample mean (x_bar), sample standard deviation (s),
# sample size (n) and confidence level

x_bar = 63.66
s = 74.13
n = 30
confidence_level = 0.95

# Calculate alpha, degrees of freedom (df),
# the critical t-value, and the margin of error

alpha = (1 - confidence_level)
df = n - 1
standard_error = s / math.sqrt(n)

critical_t = stats.t.ppf(1 - alpha/2, df)
margin_of_error = critical_t * standard_error

# Calculate the lower and upper bound

lower_bound = x_bar - margin_of_error
upper_bound = x_bar + margin_of_error

# Print the results

print("Critical t-value: {:.3f}".format(critical_t))
print("Margin of Error: {:.3f}".format(margin_of_error))
print("Confidence Interval: [{:.3f}, {:.3f}]".format(lower_bound, upper_bound))
print("The {:.1%} confidence interval for the population mean is:".format(confidence_level))
print("between {:.3f} and {:.3f}".format(lower_bound, upper_bound))
# Out:
# Critical t-value: 2.045
# Margin of Error: 27.681
# Confidence Interval: [35.979, 91.341]
# The 95.0% confidence interval for the population mean is:
# between 35.979 and 91.341
